# %% [markdown]
# <a href="https://colab.research.google.com/github/kyawzinthant-it/sharing-github/blob/master/DhamaEducation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MOHS မှ နေ့စဉ်သတင်းထုတ်ပြန်ချက်များကို Report များအားတိုက်ရိုက် ကြည့်ရှုနိုင်ပါပြီ

# %%
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_da155df6_7cda_11ea_b98f_0242ac1c0002row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row0_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row1_col1 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row1_col3 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row1_col4 {
#             background-color:  #fee1d4;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row2_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row2_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row2_col4 {
#             background-color:  #fee1d4;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row3_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row3_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row3_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row3_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row4_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row4_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row4_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row4_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row5_col1 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row5_col4 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row6_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row6_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row6_col4 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row7_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row7_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row7_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row7_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row8_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row8_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row8_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row8_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row9_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row9_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row9_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row10_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row10_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row10_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row10_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row11_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row11_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row11_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row11_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row12_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row12_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row12_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row12_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row13_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row13_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row13_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row13_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row14_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row14_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row14_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_da155df6_7cda_11ea_b98f_0242ac1c0002row14_col4 {
#             background-color:  #fff5f0;

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
#style.use('ggplot')
# %matplotlib inline

import plotly
import plotly.express as px
import plotly.graph_objects as go

import cufflinks as cf
import plotly.offline as pyo
from plotly.offline import init_notebook_mode,plot,iplot

import folium

# %%
pyo.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("https://raw.githubusercontent.com/kyawzinthant-it/sharing-github/master/Covid-cases-in-myanmar.csv")

# %%
df
# Out:
#     S. No. Name of State  COVID-19 confirmed cases  Recovered  Deaths  Update
# 0        1        Yangon                        27          0       2     1.0
# 1        2          Bago                         4          0       1     NaN
# 2        3          Chin                         3          0       0     1.0
# 3        4      Mandalay                         1          1       0     NaN
# 4        5     Naypyidaw                         1          1       0     NaN
# 5        6          Shan                         2          0       0     1.0
# 6        7           Mon                         1          0       0     NaN
# 7        8        Magway                         0          0       0     NaN
# 8        9         Kayar                         0          0       0     NaN
# 9       10         Kayin                         0          0       0     NaN
# 10      11       Sagaing                         0          0       0     NaN
# 11      12   Ayeyarwaddy                         0          0       0     NaN
# 12      13       Rakhine                         0          0       0     NaN
# 13      14        Kachin                         0          0       0     NaN
# 14      15  Thanintharyi                         0          0       0     NaN

# %%
df.drop(['S. No.'],axis=1,inplace=True)
df.drop(['Update'],axis=1,inplace=True)

# %%
df
# Out:
#    Name of State  COVID-19 confirmed cases  Recovered  Deaths
# 0         Yangon                        27          0       2
# 1           Bago                         4          0       1
# 2           Chin                         3          0       0
# 3       Mandalay                         1          1       0
# 4      Naypyidaw                         1          1       0
# 5           Shan                         2          0       0
# 6            Mon                         1          0       0
# 7         Magway                         0          0       0
# 8          Kayar                         0          0       0
# 9          Kayin                         0          0       0
# 10       Sagaing                         0          0       0
# 11   Ayeyarwaddy                         0          0       0
# 12       Rakhine                         0          0       0
# 13        Kachin                         0          0       0
# 14  Thanintharyi                         0          0       0

# %%
total_cases_overall=df['COVID-19 confirmed cases'].sum()
print('The total number cases till now in Myanmar is', total_cases_overall)
# Out:
# The total number cases till now in Myanmar is 39

# %%
total_cases_overall=df['Recovered'].sum()
print('The total number Recovered cases till now in Myanmar is', total_cases_overall)
# Out:
# The total number Recovered cases till now in Myanmar is 2

# %%
total_cases_overall=df['Deaths'].sum()
print('The total number Deaths cases till now in Myanmar is', total_cases_overall)
# Out:
# The total number Deaths cases till now in Myanmar is 3

# %%
Total_deaths_recovered = df['Recovered']+df['Deaths']
df['Active Cases']=df['COVID-19 confirmed cases']-Total_deaths_recovered

# %%
df
# Out:
#    Name of State  COVID-19 confirmed cases  Recovered  Deaths  Active Cases
# 0         Yangon                        27          0       2            25
# 1           Bago                         4          0       1             3
# 2           Chin                         3          0       0             3
# 3       Mandalay                         1          1       0             0
# 4      Naypyidaw                         1          1       0             0
# 5           Shan                         2          0       0             2
# 6            Mon                         1          0       0             1
# 7         Magway                         0          0       0             0
# 8          Kayar                         0          0       0             0
# 9          Kayin                         0          0       0             0
# 10       Sagaing                         0          0       0             0
# 11   Ayeyarwaddy                         0          0       0             0
# 12       Rakhine                         0          0       0             0
# 13        Kachin                         0          0       0             0
# 14  Thanintharyi                         0          0       0             0
